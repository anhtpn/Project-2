# %%
import numpy as np
import json
import re
import pandas as pd

# %%
data = pd.read_excel('LoiGiai_daydu.xlsx')
Loi_giai_neu = list(data['Loi_giai_neu'])
Loi_giai_neu[0]
# Out:
# 'Mệnh có Tử Vi'

# %%
regex0 = [r'Có (.*) tại (.*), người tuổi (.*)']
regex1 = [r'(.*) tại (.*) có (.*) gặp (.*) hội họp, người tuổi (.*)']
regex2 = [r'(.*) tại (.*) có (.*) không gặp (.*), người tuổi (.*)']
regex3 = [r'(.*) tại (.*) có (.*) gặp (.*), người tuổi (.*)']
regex4 = [r'(.*) tại (.*) có (.*) chiếu, người tuổi (.*)']
regex5 = [r'(.*) tại (.*) có (.*), người tuổi (.*)']
regex6 = [r'(.*) có (.*) tại (.*) gặp (.*), người tuổi (.*)']
regex7 = [r'(.*) có (.*) tại (.*), người tuổi (.*)']
regex8 = [r'(.*) có (.*) gặp (.*) hội họp, người tuổi (.*)']
regex9 = [r'(.*) có (.*) gặp (.*), người tuổi (.*)']
regex10 = [r'(.*) có (.*), người tuổi (.*)']
regex11 = [r'(.*) tại (.*) gặp (.*) và không gặp (.*), người tuổi (.*)']
regex12 = [r'(.*) tại (.*) không gặp (.*) hội họp, người tuổi (.*)']
regex13 = [r'(.*) tại (.*) không gặp (.*), người tuổi (.*)']
regex14 = [r'(.*) tại (.*) gặp (.*) hội họp, người tuổi (.*)']
regex15 = [r'(.*) tại (.*) gặp (.*), người tuổi (.*)']
regex16 = [r'(.*) hội họp, người tuổi (.*)']

regex17 = [r'Có (.*) tại (.*)']
regex18 = [r'(.*) ở vượng địa']

regex19 = [r'(.*) có (.*) đồng cung gặp (.*) chiếu']
regex20 = [r'(.*) có (.*) đồng cung gặp (.*)']
regex21 = [r'(.*) có (.*) gặp (.*) đồng cung chiếu']
regex22 = [r'(.*) có (.*) không gặp (.*)']
regex23 = [r'(.*) có (.*) tại (.*) giáp (.*)']
regex24 = [r'(.*) có (.*) tại (.*) gặp (.*)']
regex25 = [r'(.*) có (.*) tại (.*)']
regex26 = [r'(.*) có (.*) gặp (.*) hội họp']
regex27 = [r'(.*) có (.*) gặp (.*) chiếu']
regex28 = [r'(.*) có (.*) gặp (.*)']
regex29 = [r'(.*) có (.*) đồng cung']
regex30 = [r'(.*) có (.*) chiếu']
regex31 = [r'(.*) có (.*)']

regex32 = [r'(.*) tại (.*) có (.*) không gặp (.*)']
regex33 = [r'(.*) tại cung (.*) có (.*) gặp (.*)']
regex34 = [r'(.*) tại (.*) có (.*) gặp (.*) hội họp']
regex35 = [r'(.*) tại (.*) có (.*) gặp (.*) chiếu']
regex36 = [r'(.*) tại (.*) có (.*) gặp (.*)']
regex37 = [r'(.*) tại cung (.*) có (.*)']
regex38 = [r'(.*) tại (.*) có (.*) chiếu']
regex39 = [r'(.*) tại (.*) có (.*)']

regex40 = [r'(.*) tại (.*) gặp (.*) và không gặp (.*)']
regex41 = [r'(.*) gặp (.*) và không gặp (.*)']
regex42 = [r'(.*) không gặp (.*)']
regex43 = [r'(.*) tại cung (.*) gặp (.*) hội họp']
regex44 = [r'(.*) tại cung (.*) gặp (.*)']
regex45 = [r'(.*) tại cung (.*) giáp (.*)']
regex46 = [r'(.*) tại (.*) gặp (.*) hội họp']
regex47 = [r'(.*) tại (.*) gặp (.*) chiếu']
regex48 = [r'(.*) tại (.*) gặp (.*)']
regex49 = [r'(.*) tại (.*)']
regex50 = [r'(.*) gặp (.*) hội họp']
regex51 = [r'(.*) gặp (.*) chiếu']
regex52 = [r'(.*) gặp (.*)']
regex53 = [r'(.*) hội họp']
regex54 = [r'(.*) đồng cung']

# regex55 = [r'Giáp (.*) giáp (.*) miếu vượng']
# regex56 = [r'Giáp (.*) giáp (.*)']
# regex57 = [r'Giáp (.*)']

regex_list1 = regex0 + regex1 + regex2 + regex3 + regex4 + regex5 + regex6 + regex7 + regex8 + regex9 + regex10 + regex11 + regex12 + regex13 + regex14 + regex15 + regex16
regex_list2 = regex17 + regex18
regex_list4 = regex32 + regex33 + regex34 + regex35 + regex36 + regex37 + regex38 + regex39
regex_list3 = regex19 + regex20 + regex21 + regex22 + regex23 + regex24 + regex25 + regex26 + regex27 + regex28 + regex29 + regex30 + regex31
regex_list5 = regex40 + regex41 + regex42 + regex43 + regex44 + regex45 + regex46 + regex47 + regex48 + regex49 + regex50 + regex51 + regex52 + regex53 + regex54
# regex_list6 = regex55 + regex56 + regex57
regex_list = regex_list1 + regex_list2 + regex_list4 + regex_list3 + regex_list5 #+ regex_list6
len(regex_list)
# Out:
# 55

# %%
Cung_list = []
Chi_list = []
Sao_list1 = []
Sao_list2 = []
Sao_list3 = []
Can_list = []
for i in range(len(Loi_giai_neu)):
    if re.match(regex_list[0], Loi_giai_neu[i]):
        a = re.match(regex_list[0], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append(a[3])
        continue
    elif re.match(regex_list[1], Loi_giai_neu[i]):
        a = re.match(regex_list[1], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append(a[5])
        continue   
    elif re.match(regex_list[2], Loi_giai_neu[i]):
        a = re.match(regex_list[2], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append('')
        Sao_list3.append(a[4])
        Can_list.append(a[5])
        continue        
    elif re.match(regex_list[3], Loi_giai_neu[i]):
        a = re.match(regex_list[3], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append(a[5])
        continue            
    elif re.match(regex_list[4], Loi_giai_neu[i]):
        a = re.match(regex_list[4], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[5], Loi_giai_neu[i]):
        a = re.match(regex_list[5], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[6], Loi_giai_neu[i]):
        a = re.match(regex_list[6], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[3])
        Sao_list1.append(a[2])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append(a[5])
        continue
    elif re.match(regex_list[7], Loi_giai_neu[i]):
        a = re.match(regex_list[7], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[3])
        Sao_list1.append(a[2])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[8], Loi_giai_neu[i]):
        a = re.match(regex_list[8], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[9], Loi_giai_neu[i]):
        a = re.match(regex_list[9], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[10], Loi_giai_neu[i]):
        a = re.match(regex_list[10], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append(a[3])
        continue
    elif re.match(regex_list[11], Loi_giai_neu[i]):
        a = re.match(regex_list[11], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append(a[4])
        Can_list.append(a[5])
        continue
    elif re.match(regex_list[12], Loi_giai_neu[i]):
        a = re.match(regex_list[12], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append(a[3])
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[13], Loi_giai_neu[i]):
        a = re.match(regex_list[13], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append(a[3])
        Can_list.append(a[4])
        continue      
    elif re.match(regex_list[14], Loi_giai_neu[i]):
        a = re.match(regex_list[14], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[15], Loi_giai_neu[i]):
        a = re.match(regex_list[15], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append(a[4])
        continue
    elif re.match(regex_list[16], Loi_giai_neu[i]):
        a = re.match(regex_list[16], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append(a[2])
        continue    
    elif re.match(regex_list[17], Loi_giai_neu[i]):
        a = re.match(regex_list[17], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[18], Loi_giai_neu[i]):
        a = re.match(regex_list[18], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[19], Loi_giai_neu[i]):
        a = re.match(regex_list[19], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append('')
        Sao_list3.append(a[4])
        Can_list.append('')
        continue
    elif re.match(regex_list[20], Loi_giai_neu[i]):
        a = re.match(regex_list[20], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[21], Loi_giai_neu[i]):
        a = re.match(regex_list[21], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[22], Loi_giai_neu[i]):
        a = re.match(regex_list[22], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[23], Loi_giai_neu[i]):
        a = re.match(regex_list[23], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[24], Loi_giai_neu[i]):
        a = re.match(regex_list[24], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[25], Loi_giai_neu[i]):
        a = re.match(regex_list[25], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[26], Loi_giai_neu[i]):
        a = re.match(regex_list[26], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append(a[3])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[27], Loi_giai_neu[i]):
        a = re.match(regex_list[27], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[28], Loi_giai_neu[i]):
        a = re.match(regex_list[28], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[29], Loi_giai_neu[i]):
        a = re.match(regex_list[29], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[30], Loi_giai_neu[i]):
        a = re.match(regex_list[30], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append('')
        Sao_list3.append(a[3])
        Can_list.append('')
        continue
    elif re.match(regex_list[31], Loi_giai_neu[i]):
        a = re.match(regex_list[31], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[3])
        Sao_list1.append(a[2])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[32], Loi_giai_neu[i]):
        a = re.match(regex_list[32], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[3])
        Sao_list1.append(a[2])
        Sao_list2.append(a[4])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[33], Loi_giai_neu[i]):
        a = re.match(regex_list[33], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[3])
        Sao_list1.append(a[2])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[34], Loi_giai_neu[i]):
        a = re.match(regex_list[34], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[35], Loi_giai_neu[i]):
        a = re.match(regex_list[35], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[36], Loi_giai_neu[i]):
        a = re.match(regex_list[36], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[37], Loi_giai_neu[i]):
        a = re.match(regex_list[37], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[38], Loi_giai_neu[i]):
        a = re.match(regex_list[38], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[39], Loi_giai_neu[i]):
        a = re.match(regex_list[39], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append('')
        Sao_list1.append(a[2])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[40], Loi_giai_neu[i]):
        a = re.match(regex_list[40], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append(a[4])
        Can_list.append('')
        continue
    elif re.match(regex_list[41], Loi_giai_neu[i]):
        a = re.match(regex_list[41], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append(a[2])
        Sao_list3.append(a[3])
        Can_list.append('')
        continue
    elif re.match(regex_list[42], Loi_giai_neu[i]):
        a = re.match(regex_list[42], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append(a[2])
        Can_list.append('')
        continue
    elif re.match(regex_list[43], Loi_giai_neu[i]):
        a = re.match(regex_list[43], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[44], Loi_giai_neu[i]):
        a = re.match(regex_list[44], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[45], Loi_giai_neu[i]):
        a = re.match(regex_list[45], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[46], Loi_giai_neu[i]):
        a = re.match(regex_list[46], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[47], Loi_giai_neu[i]):
        a = re.match(regex_list[47], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[48], Loi_giai_neu[i]):
        a = re.match(regex_list[48], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append(a[2])
        Sao_list1.append(a[1])
        Sao_list2.append(a[3])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[49], Loi_giai_neu[i]):
        a = re.match(regex_list[49], Loi_giai_neu[i])
        Cung_list.append(a[1])
        Chi_list.append(a[2])
        Sao_list1.append('')
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[50], Loi_giai_neu[i]):
        a = re.match(regex_list[50], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append(a[2])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[51], Loi_giai_neu[i]):
        a = re.match(regex_list[51], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append(a[2])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[52], Loi_giai_neu[i]):
        a = re.match(regex_list[52], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append(a[2])
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[53], Loi_giai_neu[i]):
        a = re.match(regex_list[53], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
    elif re.match(regex_list[54], Loi_giai_neu[i]):
        a = re.match(regex_list[54], Loi_giai_neu[i])
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append(a[1])
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')
        continue
#     elif re.match(regex_list[55], Loi_giai_neu[i]):
#         a = re.match(regex_list[55], Loi_giai_neu[i])
#         Cung_list.append('')
#         Chi_list.append('')
#         Sao_list1.append(a[1] + ', ' + a[2])
#         Sao_list2.append('')
#         Sao_list3.append('')
#         Can_list.append('')
#         continue
#     elif re.match(regex_list[56], Loi_giai_neu[i]):
#         a = re.match(regex_list[56], Loi_giai_neu[i])
#         Cung_list.append('')
#         Chi_list.append('')
#         Sao_list1.append(a[1] + ', ' + a[2])
#         Sao_list2.append('')
#         Sao_list3.append('')
#         Can_list.append('')
#         continue
#     elif re.match(regex_list[57], Loi_giai_neu[i]):
#         a = re.match(regex_list[57], Loi_giai_neu[i])
#         Cung_list.append('')
#         Chi_list.append('')
#         Sao_list1.append(a[1])
#         Sao_list2.append('')
#         Sao_list3.append('')
#         Can_list.append('')
        continue
    else:
        Cung_list.append('')
        Chi_list.append('')
        Sao_list1.append('')
        Sao_list2.append('')
        Sao_list3.append('')
        Can_list.append('')

# %%
# data['Cung'] = Cung_list
# data['Chi'] = Chi_list
# data['Sao1'] = Sao_list1
# data['Sao2'] = Sao_list2
# data['Sao3'] = Sao_list3
# data['Can'] = Can_list
# data.to_excel('./Information_Extraction.xlsx', index=False)

# %%
id_Loigiai = list(data['id_Loigiai'])
id_category = list(data['id_category'])
id_CauPhu = list(data['id_CauPhu'])
count = 1 
manual_list = [54, 55, 56, 57, 66, 67, 468, 469, 1238, 1239, 1294, 1295, 1366, 1404, 723, 724, 725, 726, 727, 796, 815, 957, 958, 959, 960, 961, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034, 1458, 1459, 1460, 1461, 1462, 1491, 1492, 1493, 1494, 1495, 1496, 1497, 1498, 1499]
Rules_list_or = []
for i in range(len(data)): 
    if i not in manual_list:
        if ',' in Chi_list[i]:
            Chi = [chi.strip() for chi in Chi_list[i].split(',')]
        else:
            Chi = [Chi_list[i]]
        if ',' in Sao_list2[i]:
            Sao2 = [sao2.strip() for sao2 in Sao_list2[i].split(',')]
        else:
            Sao2 = [Sao_list2[i]]
        if ',' in Can_list[i]:
            Can = [can.strip() for can in Can_list[i].split(',')]
        else:
            Can = [Can_list[i]]
        for chi in Chi:
            for sao2 in Sao2:
                for can in Can:
                    Rules_list_or.append([count, Cung_list[i], chi, Sao_list1[i], sao2, Sao_list3[i], can, id_Loigiai[i], id_CauPhu[i], id_category[i]])
                    count += 1
    else:
        Rules_list_or.append([count, '', '', '', '', '', '', id_Loigiai[i], id_CauPhu[i], id_category[i]])
        count += 1

# %%
#Rules_list_or

# %%
df = pd.DataFrame(Rules_list_or, columns=['Rule_id', 'Cung', 'Chi', 'Sao1', 'Sao2', 'Sao3', 'Can', 'id_Loigiai', 'id_CauPhu', 'id_category'])
# df.to_excel('./Rules_or_Extraction.xlsx', index=False)

# %%
df.replace(np.nan, '', inplace=True)
id_category = list(df['id_category'])
Rule_id = list(df['Rule_id'])
id_Loigiai = list(df['id_Loigiai'])
id_CauPhu = list(df['id_CauPhu'])
Cung_list = list(df['Cung'])
Chi_list = list(df['Chi'])
Sao_list1 = list(df['Sao1'])
Sao_list2 = list(df['Sao2'])
Sao_list3 = list(df['Sao3'])
Can_list = list(df['Can'])

# %%
for i in range(len(Sao_list1)):
    if Sao_list2[i] == '':
        continue
    else:
        Sao_list1[i] = Sao_list1[i] + ', ' + Sao_list2[i]

# %%
Rules_list_and = []
for i in range(len(Rule_id)):
    if ',' in Cung_list[i]:
        Cung = [cung.strip() for cung in Cung_list[i].split(',')]
    else:
        Cung = [Cung_list[i]]
    if ',' in Sao_list1[i]:
        Sao1 = [sao1.strip() for sao1 in Sao_list1[i].split(',')]
    else:
        Sao1 = [Sao_list1[i]]
    if ',' in Sao_list3[i]:
        Sao3 = [sao3.strip() for sao3 in Sao_list3[i].split(',')]
    else:
        Sao3 = [Sao_list3[i]]
    for cung in Cung:
        for sao1 in Sao1:
            for sao3 in Sao3:
                Rules_list_and.append([Rule_id[i], cung, Chi_list[i], sao1, sao3, Can_list[i], id_Loigiai[i], id_CauPhu[i], id_category[i]])

# %%
df = pd.DataFrame(Rules_list_and, columns=['Rule_id', 'Cung', 'Chi', 'Sao', 'not_Sao', 'Can', 'id_Loigiai', 'id_CauPhu', 'id_category'])
# df.to_excel('./Rules_and_Extraction_new.xlsx', index=False)
